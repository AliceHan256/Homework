# %%
# -*- coding: UTF-8 -*-
"""PyRamen Homework Starter."""

# Import libraries
import csv
from pathlib import Path

# Set file paths for menu_data.csv and sales_data.csv
menu_filepath = Path('resourses/menu_data.csv')
sales_filepath = Path('resourses/sales_data.csv')

# Initialize list objects to hold our menu and sales data
menu = []
sales = []
# Initialize variable of line number
line_num = 0

# @TODO: Read in the menu data into the menu list
with open(menu_filepath, 'r') as csvfile:
    
    # Apply csv.reader() function and ',' separator to generate the csvreader object
    menureader = csv.reader(csvfile, delimiter = ',')
    
    #  Read the header row followed by each row from the generated csvreader object
    menu_header = next(menureader)
    
    line_num += 1
    
    for row in menureader:
        
        # Name each column for better readability and convert string to ints for profit/loss calculations
        # Convert string to float for numerical calculation
        item_name = row[0]
        category = row[1]
        description = row[2]
        price = float(row[3])
        cost = float(row[4])

        # Append every row to the menu list object
        menu.append(row)

# @TODO: Read in the sales data into the sales list
with open(sales_filepath, 'r') as csvfile:
    
    # Apply csv.reader() function and ',' separator to generate the csvreader object
    salesreader = csv.reader(csvfile, delimiter = ',')
    
    #  Read the header row followed by each row from the generated csvreader object
    sales_header = next(salesreader)
    
    row_count += 1
   
    for sales_row in salesreader:
        
        # Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_Item
        # @TODO: Initialize sales data variables
        # Convert string to int for numerical calculation
        line_item_id = int(sales_row[0])
        date = sales_row[1]
        credit_card_number = sales_row[2]
        quantity = int(sales_row[3])
        menu_item = sales_row[4]

        # Append every row to the sales list object
        sales.append(sales_row)
        
# @TODO: Initialize dict object to hold our key-value pairs of items and metrics
report = {}

# Initialize a row counter variable
menu_item_count = 0

# @TODO: Loop over every row in the sales list object
for element_in_sales in sales:
    sales_qty = int(element_in_sales[3])
    sales_item = element_in_sales[4]

    # @TODO:
    # If the item value not in the report, add it as a new entry with initialized metrics
    # Naming convention allows the keys to be ordered in logical fashion, count, revenue, cost, profit

    if sales_item not in report.keys():
        report[sales_item] = {"01-count": 0,
                              "02-revenue": 0,
                              "03-cogs": 0,
                              "04-profit": 0,
                             }

        # @TODO: For every row in our sales data, loop over the menu records to determine a match

        for element_in_menu in menu:

            # Item,Category,Description,Price,Cost
            # @TODO: Initialize menu data variables
            menu_item = element_in_menu[0]
            menu_price = float(element_in_menu[3])
            menu_cost = float(element_in_menu[4])
            
            # @TODO: Calculate profit of each item in the menu data
            menu_profit = menu_price - menu_cost
           
            # @TODO: If the item value in our sales data is equal to the any of the items in the menu, then begin tracking metrics for that item
            if sales_item == menu_item:
                
              # @TODO: Print out matching menu data
                print(f"{sales_item} in sales_data can be found in menu_data.")
                print(f"Price: {menu_price}")
                print(f"Cost: {menu_cost}")
                print(f"Profit: {menu_profit}")
                
              # @TODO: Cumulatively add up the metrics for each item key
                report[sales_item]["01-count"] += sales_qty
                report[sales_item]["02-revenue"] += menu_price * sales_qty
                report[sales_item]["03-cogs"] += menu_cost * sales_qty
                report[sales_item]["04-profit"] += menu_profit * sales_qty

            # @TODO: Else, the sales item does not equal any of the item in the menu data, therefore no match
            else:
                print(f"{sales_item} does not equal {menu_item}! NO MATCH!")

    # @TODO: Increment the row counter by 1
    menu_item_count += 1

# @TODO: Print total number of records in sales data
print()
print("Total number of records", menu_item_count)
print()

# @TODO: Write out report to a text file (won't appear on the command line output)

# Set the output file path
output_path = Path("output.txt")

# Open the output path as a file object to contain written text
with open("output_path", 'w') as txt_file:
    for key, value in report.items():
        line = f"{key} {value}\n"
        txt_file.write(line)
# Out:
# spicy miso ramen does not equal edamame! NO MATCH!
# spicy miso ramen does not equal house salad! NO MATCH!
# spicy miso ramen does not equal cucumber sunomono salad! NO MATCH!
# spicy miso ramen does not equal hiyashi wakame seaweed salad! NO MATCH!
# spicy miso ramen does not equal agedashi tofu! NO MATCH!
# spicy miso ramen does not equal hiyayakko tofu! NO MATCH!
# spicy miso ramen does not equal pork floss bao! NO MATCH!
# spicy miso ramen does not equal kakuni bao! NO MATCH!
# spicy miso ramen does not equal edamame fried gyoza (vegan)! NO MATCH!
# spicy miso ramen does not equal fried gyoza! NO MATCH!
# spicy miso ramen does not equal takoyaki! NO MATCH!
# spicy miso ramen does not equal rock shrimp tempura! NO MATCH!
# spicy miso ramen does not equal soft-shell crab tempura! NO MATCH!
# spicy miso ramen does not equal ebi katsu shrimp bao! NO MATCH!
# spicy miso ramen does not equal nagomi shoyu! NO MATCH!
# spicy miso ramen does not equal shio ramen! NO MATCH!
# ...
